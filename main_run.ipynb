# %%
import wandb
from sumolib import checkBinary
import Genetic_Algorithm as GA
import Simulation_Generator as sg
import numpy as np

# %%
#Initialize Weights and Biases
wandb.init(project="Manhattan 5x3 Genetic Algorithm", entity="dharma")

#SUMO parameters
sumo_binary = checkBinary('sumo')
sumo_binary_gui = checkBinary('sumo-gui')
config_file = 'Manhattan5x3.sumocfg'

pop_size = 12
max_generations = 20  
n_survivors = 5

#Mutation and Crossover parameters
crossover_rate=0.5
duration_mutation_rate=0.2
duration_mutation_strength=15
states_mutation_rate = 0.2
light_options = ['G', 'y', 'r']


#Fitness Function parameters
collision_penalty   = [400,4000,10000,400,4000]
waiting_time_weight = [10/20000,15/2000,5/2000,20/2000]
emissions_weight    = [10/20000,5/2000,15/2000,0/2000]


# Launch 5 simulated experiments
total_runs = 5
for run in range(total_runs):
  # 🐝 1️⃣ Start a new run to track this script
    wandb.init(
      # Set the project where this run will be logged
      project="Manhattan5x3_GA", 
      entity="dharma",
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"GA_270321_{run}",
      # Track hyperparameters and run metadata
      config={
        "config_file":config_file,
        "collision_penalty": collision_penalty[run],
        "waiting_time_weight": waiting_time_weight[run],
        "emissions_weight": emissions_weight[run],
        "architecture": "Genetic Algorithm",
        "population_size": pop_size,
        "max_generations":max_generations,
        "n_survivors":n_survivors,
        "crossover_rate":crossover_rate,
        "duration_mutation_rate":duration_mutation_rate,
        "duration_mutation_strength":duration_mutation_strength,
        "states_mutation_rate":states_mutation_rate       
      }
    )

    #Get Base chromosome
    chromosome_base = GA.get_chromosome()
    GA_pop_next = GA.generate_random_population(chromosome_base)
    current_gen = 0
    #Generations=[]
    
    #Run GA
    while(current_gen <max_generations):
        GA_pop = GA_pop_next
        
        
        ## Evaluating Population
        fitness, emissions, waiting = GA_pop.evaluate_pop()
        #Generations.append([GA_pop.generation,GA_pop.best_fitness,GA_pop.best_emissions,GA_pop.best_waiting_time,
        #                    GA_pop.avg_fitness,GA_pop.avg_emissions,GA_pop.avg_waiting_time])

        print("Best Fitness value in Generation ",current_gen, " is ",GA_pop.best_fitness)

        #Logging data to Weights and Biases
        best_fitness = GA_pop.best_fitness
        best_emissions = GA_pop.best_emissions
        best_waiting_time = GA_pop.best_waiting_time
        avg_fitness = GA_pop.avg_fitness
        avg_emissions = GA_pop.avg_emissions
        avg_waiting_time = GA_pop.avg_waiting_time

        print("Logging info to WandB")
        wandb.log({"best_fitness":best_fitness,"best_emissions":best_emissions,"best_waiting_time":best_waiting_time,
                   "avg_fitness":avg_fitness, "avg_emissions":avg_emissions,"avg_waiting_time":avg_waiting_time})
        
        
        ## Visualize SUMO run
        if current_gen // 5 == 0:
            GA.visualize_SUMO(GA_pop.best_individual)
        
        #Calculating Survivors
        sorted_pop = np.argsort(fitness)[:n_survivors]
        Next_gene_pool = [GA_pop.gene_pool[idx] for idx in sorted_pop]
        
        #Creating new Generation
        while len(Next_gene_pool) < pop_size:

            chromosome_male =GA_pop.gene_pool[int(np.random.uniform(0,n_survivors))]
            chromosome_female=GA_pop.gene_pool[int(np.random.uniform(0,n_survivors))]
            chromosome_child = GA.crossover_parent(chromosome_male, chromosome_female,crossover_rate)
            chromosome_child = GA.mutate_chromosome(chromosome_child,0.1,5,0.2)
            Next_gene_pool.append(chromosome_child)

        current_gen = current_gen+1
        GA_pop_next = GA.population(current_gen)
        GA_pop_next.gene_pool = Next_gene_pool

    wandb.finish()
# Out:
# wandb: Currently logged in as: dharma (use `wandb login --relogin` to force relogin)
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\rohit\Personal Projects\Traffic Lights Genetic Algorithm\wandb\run-20220327_083458-15r3ut2l</code>
# Syncing run <strong><a href="https://wandb.ai/dharma/Manhattan%205x3%20Genetic%20Algorithm/runs/15r3ut2l" target="_blank">dainty-galaxy-7</a></strong> to <a href="https://wandb.ai/dharma/Manhattan%205x3%20Genetic%20Algorithm" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Finishing last run (ID:15r3ut2l) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">dainty-galaxy-7</strong>: <a href="https://wandb.ai/dharma/Manhattan%205x3%20Genetic%20Algorithm/runs/15r3ut2l" target="_blank">https://wandb.ai/dharma/Manhattan%205x3%20Genetic%20Algorithm/runs/15r3ut2l</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220327_083458-15r3ut2l\logs</code>
# Successfully finished last run (ID:15r3ut2l). Initializing new run:<br/>
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\rohit\Personal Projects\Traffic Lights Genetic Algorithm\wandb\run-20220327_083500-1pi4bj9i</code>
# Syncing run <strong><a href="https://wandb.ai/dharma/Manhattan5x3_GA/runs/1pi4bj9i" target="_blank">GA_270321_0</a></strong> to <a href="https://wandb.ai/dharma/Manhattan5x3_GA" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# SUMO launched: Collecting Traffic Lights
# <traci.connection.Connection object at 0x00000203120E6F40>
# Generation: 0  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x000002031210F610>
# Generation: 0  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x00000203120242E0>
# Generation: 0  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x00000203121178E0>
# Generation: 0  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x0000020312126760>
# Generation: 0  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203121261F0>
# Generation: 0  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x0000020312117640>
# Generation: 0  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x0000020312126040>
# Generation: 0  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x000002031212DEE0>
# Generation: 0  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x000002031212D5B0>
# Generation: 0  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x0000020312144EE0>
# Generation: 0  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x0000020312144F70>
# Generation: 0  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x0000020312126280>
# Generation: 0  Individual:  12
# SUMO launched
# <traci.connection.Connection object at 0x0000020312117C70>
# Generation: 0  Individual:  13
# SUMO launched
# <traci.connection.Connection object at 0x000002031212DF10>
# Generation: 0  Individual:  14
# SUMO launched
# <traci.connection.Connection object at 0x000002031215CAF0>
# Best Fitness value in Generation  0  is  346395626006
# Logging info to WandB
# Generation: 1  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x00000203120EFCD0>
# Generation: 1  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x00000203120EFC10>
# Generation: 1  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x000002031218EFA0>
# Generation: 1  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x000002031218E7C0>
# Generation: 1  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203121625B0>
# Generation: 1  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x0000020312109FA0>
# Generation: 1  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x0000020312197D60>
# Generation: 1  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x000002031216E460>
# Generation: 1  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x000002031218EFD0>
# Generation: 1  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x000002031218EEE0>
# Generation: 1  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x0000020312153CD0>
# Generation: 1  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x000002031219EDC0>
# Best Fitness value in Generation  1  is  344977343917
# Logging info to WandB
# Generation: 2  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x00000203120EF310>
# Generation: 2  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x0000020312186970>
# Generation: 2  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x0000020312186B20>
# Generation: 2  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x0000020312117430>
# Generation: 2  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203120EF1F0>
# Generation: 2  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x0000020312186460>
# Generation: 2  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BC160>
# Generation: 2  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x000002031202CCD0>
# Generation: 2  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x00000203121865B0>
# Generation: 2  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x0000020312186850>
# Generation: 2  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x000002031211C3A0>
# Generation: 2  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x0000020312186AC0>
# Best Fitness value in Generation  2  is  344977343917
# Logging info to WandB
# Generation: 3  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x000002
Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x00000203128532B0>
# Generation: 17  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x00000203121498B0>
# Generation: 17  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x000002031286DF40>
# Generation: 17  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x000002031286DAF0>
# Generation: 17  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x000002031213E430>
# Generation: 17  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x0000020312171490>
# Generation: 17  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x00000203120EF730>
# Generation: 17  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x00000203120EF940>
# Generation: 17  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x0000020312185400>
# Generation: 17  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x0000020312185100>
# Generation: 17  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x0000020312117610>
# Generation: 17  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x0000020312117DC0>
# Best Fitness value in Generation  17  is  62158731253
# Logging info to WandB
# Generation: 18  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x00000203120EFB50>
# Generation: 18  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x000002031212D070>
# Generation: 18  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x000002031212D9D0>
# Generation: 18  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x00000203121172B0>
# Generation: 18  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BCA30>
# Generation: 18  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BCE80>
# Generation: 18  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x00000203121BFEE0>
# Generation: 18  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BCF70>
# Generation: 18  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x0000020312004A60>
# Generation: 18  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x0000020312180820>
# Generation: 18  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x0000020312180940>
# Generation: 18  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x00000203121AE1F0>
# Best Fitness value in Generation  18  is  62158731253
# Logging info to WandB
# Generation: 19  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x0000020312024F70>
# Generation: 19  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x0000020312097490>
# Generation: 19  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x00000203121AE520>
# Generation: 19  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x00000203120979A0>
# Generation: 19  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x0000020312853C40>
# Generation: 19  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x00000203121711F0>
# Generation: 19  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x00000203121AE130>
# Generation: 19  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x0000020312171970>
# Generation: 19  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x000002031210F940>
# Generation: 19  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x00000203120CF880>
# Generation: 19  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x00000203120CF220>
# Generation: 19  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x00000203120244C0>
# Best Fitness value in Generation  19  is  62158731253
# Logging info to WandB
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_emissions</td><td>█▃▃▂▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁</td></tr><tr><td>avg_fitness</td><td>█▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>avg_waiting_time</td><td>█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▃▁▁▁▁</td></tr><tr><td>best_emissions</td><td>█████████▇▇▇▇▇▇▇▁▁▁▁</td></tr><tr><td>best_fitness</td><td>████████████████▁▁▁▁</td></tr><tr><td>best_waiting_time</td><td>█▇▇▇▇▇▇▆▆▅▅▅▅▅▅▅▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_emissions</td><td>502278197.41667</td></tr><tr><td>avg_fitness</td><td>307139977103.6667</td></tr><tr><td>avg_waiting_time</td><td>1675780.75</td></tr><tr><td>best_emissions</td><td>339339134</td></tr><tr><td>best_fitness</td><td>62158731253</td></tr><tr><td>best_waiting_time</td><td>950423</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">GA_270321_0</strong>: <a href="https://wandb.ai/dharma/Manhattan5x3_GA/runs/1pi4bj9i" target="_blank">https://wandb.ai/dharma/Manhattan5x3_GA/runs/1pi4bj9i</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220327_083500-1pi4bj9i\logs</code>
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\rohit\Personal Projects\Traffic Lights Genetic Algorithm\wandb\run-20220327_145941-3smnhyu7</code>
# Syncing run <strong><a href="https://wandb.ai/dharma/Manhattan5x3_GA/runs/3smnhyu7" target="_blank">GA_270321_1</a></strong> to <a href="https://wandb.ai/dharma/Manhattan5x3_GA" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# SUMO launched: Collecting Traffic Lights
# <traci.connection.Connection object at 0x000002031288C100>
# Generation: 0  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x000002031219D7C0>
# Generation: 0  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x0000020312185700>
# Generation: 0  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x0000020312185430>
# Generation: 0  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x0000020312171220>
# Generation: 0  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x000002031288CFD0>
# Generation: 0  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x00000203121716A0>
# Generation: 0  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x000002031288CD30>
# Generation: 0  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x000002031286DCA0>
# Generation: 0  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x000002031289BF10>
# Generation: 0  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x000002031289BDF0>
# Generation: 0  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x00000203121539D0>
# Generation: 0  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x00000203128ABAF0>
# Generation: 0  Individual:  12
# SUMO launched
# <traci.connection.Connection object at 0x00000203128ABB20>
# Generation: 0  Individual:  13
# SUMO launched
# <traci.connection.Connection object at 0x000002031289D940>
# Generation: 0  Individual:  14
# SUMO launched
# <traci.connection.Connection object at 0x00000203128AF730>
# Best Fitness value in Generation  0  is  323459678418
# Logging info to WandB
# Generation: 1  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x000002031286D790>
# Generation: 1  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x000002031286DC40>
# Generation: 1  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x000002031210FC10>
# Generation: 1  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x0000020312853F40>
# Generation: 1  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203120CFAF0>
# Generation: 1  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x000002031219D640>
# Generation: 1  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x00000203121BF100>
# Generation: 1  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x00000203121BFD30>
# Generation: 1  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x000002031286D790>
# Generation: 1  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x0000020312891D00>
# Generation: 1  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x00000203128ABC40>
# Generation: 1  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x00000203128AB6D0>
# Best Fitness value in Generation  1  is  323459678418
# Logging info to WandB
# Generation: 2  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x0000020312850850>
# Generation: 2  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BCFD0>
# Generation: 2  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x00000203121BFFD0>
# Generation: 2  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BC730>
# Generation: 2  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203120970A0>
# Generation: 2  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x0000020312097640>
# Generation: 2  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x00000203128C2FD0>
# Generation: 2  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x00000203128C3F40>
# Generation: 2  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x0000020311FF9A00>
# Generation: 2  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x00000203120CFDF0>
# Generation: 2  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x0000020311FF9970>
# Generation: 2  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x0000020312153D90>
# Best Fitness value in Generation  2  is  322507854255
# Logging info to WandB
# Generation: 3  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x000002031286D310>
# Generation: 3  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x00000203121539D0>
# Generation: 3  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x0000020312850EE0>
# Generation: 3  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x0000020312850BE0>
# Generation: 3  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203128C2A30>
# Generation: 3  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x00000203120979A0>
# Generation: 3  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x0000020311EF4970>
# Generation: 3  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x0000020312850B20>
# Generation: 3  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x00000203121713A0>
# Generation: 3  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x0000020312036550>
# Generation: 3  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BCE80>
# Generation: 3  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x00000203120365E0>
# Best Fitness value in Generation  3  is  322507854255
# Logging info to WandB
# Generation: 4  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BCE50>
# Generation: 4  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BCD60>
# Generation: 4  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x00000203121BFEB0>
# Generation: 4  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x0000020312036790>
# Generation: 4  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203121962B0>
# Generation: 4  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x00000203120EF520>
# Generation: 4  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x000002031286D3D0>
# Generation: 4  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x0000020311F693A0>
# Generation: 4  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x00000203128C2070>
# Generation: 4  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x0000020312861640>
# Generation: 4  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BC700>
# Generation: 4  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x00000203120BCE50>
# Best Fitness value in Generation  4  is  319593665400
# Logging info to WandB
# Generation: 5  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x00000203121BF370>
# Generation: 5  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x0000020311EDACA0>
# Generation: 5  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x00000203120CF8B0>
# Generation: 5  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x0000020312861160>
# Generation: 5  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203120E63A0>
# Generation: 5  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x0000020312153EB0>
# Generation: 5  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x0000020312171340>
# Generation: 5  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x000002031210F0D0>
# Generation: 5  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x000002031210F1F0>
# Generation: 5  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x0000020312131FA0>
# Generation: 5  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x0000020312131FD0>
# Generation: 5  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x00000203120EF760>
# Best Fitness value in Generation  5  is  319593665400
# Logging info to WandB
# Generation: 6  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x00000203128DA730>
# Generation: 6  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x00000203128D8E80>
# Generation: 6  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x00000203128E5400>
# Generation: 6  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x00000203128E5370>
# Generation: 6  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203120E2AF0>
# Generation: 6  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x00000203121BFBB0>
# Generation: 6  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x0000020311F69430>
# Generation: 6  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x00000203128DAA30>
# Generation: 6  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x0000020312097640>
# Generation: 6  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x00000203120EFE20>
# Generation: 6  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x00000203128E5460>
# Generation: 6  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x00000203128DB820>
# Best Fitness value in Generation  6  is  13433734590
# Logging info to WandB
# Generation: 7  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x00000
Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x0000020312273910>
# Generation: 17  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x00000203128FC9D0>
# Generation: 17  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x00000203121DB070>
# Generation: 17  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x0000020312273BB0>
# Generation: 17  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x000002031225FDF0>
# Best Fitness value in Generation  17  is  314708459347
# Logging info to WandB
# Generation: 18  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x00000203121EA880>
# Generation: 18  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x00000203120CFC70>
# Generation: 18  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x0000020312229FA0>
# Generation: 18  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x00000203121D1910>
# Generation: 18  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x0000020312273100>
# Generation: 18  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x00000203121D1790>
# Generation: 18  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x00000203120CFA90>
# Generation: 18  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x00000203120CF1C0>
# Generation: 18  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x0000020312255FA0>
# Generation: 18  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x0000020312255A30>
# Generation: 18  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x000002031286D6D0>
# Generation: 18  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x0000020312255D30>
# Best Fitness value in Generation  18  is  314708459347
# Logging info to WandB
# Generation: 19  Individual:  0
# SUMO launched
# <traci.connection.Connection object at 0x0000020312196880>
# Generation: 19  Individual:  1
# SUMO launched
# <traci.connection.Connection object at 0x0000020312267E80>
# Generation: 19  Individual:  2
# SUMO launched
# <traci.connection.Connection object at 0x0000020312196E50>
# Generation: 19  Individual:  3
# SUMO launched
# <traci.connection.Connection object at 0x00000203128F26D0>
# Generation: 19  Individual:  4
# SUMO launched
# <traci.connection.Connection object at 0x00000203128F29D0>
# Generation: 19  Individual:  5
# SUMO launched
# <traci.connection.Connection object at 0x00000203128F2160>
# Generation: 19  Individual:  6
# SUMO launched
# <traci.connection.Connection object at 0x00000203122540D0>
# Generation: 19  Individual:  7
# SUMO launched
# <traci.connection.Connection object at 0x0000020312260100>
# Generation: 19  Individual:  8
# SUMO launched
# <traci.connection.Connection object at 0x0000020312260FD0>
# Generation: 19  Individual:  9
# SUMO launched
# <traci.connection.Connection object at 0x0000020312907D30>
# Generation: 19  Individual:  10
# SUMO launched
# <traci.connection.Connection object at 0x0000020312907EE0>
# Generation: 19  Individual:  11
# SUMO launched
# <traci.connection.Connection object at 0x0000020312254CD0>
# Best Fitness value in Generation  19  is  314708459347
# Logging info to WandB
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_emissions</td><td>█▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>avg_fitness</td><td>█▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>avg_waiting_time</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>best_emissions</td><td>██▇▆▄▄▄▄▄▃▃▃▂▂▂▂▂▂▂▁</td></tr><tr><td>best_fitness</td><td>██▇▇▅▅▅▅▅▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>best_waiting_time</td><td>██▇▇▅▅▅▄▄▄▃▃▂▂▂▂▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_emissions</td><td>496803178.41667</td></tr><tr><td>avg_fitness</td><td>318983930681.0</td></tr><tr><td>avg_waiting_time</td><td>1525281.66667</td></tr><tr><td>best_emissions</td><td>486014578</td></tr><tr><td>best_fitness</td><td>314708459347</td></tr><tr><td>best_waiting_time</td><td>1410249</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">GA_270321_3</strong>: <a href="https://wandb.ai/dharma/Manhattan5x3_GA/runs/17d2zzh6" target="_blank">https://wandb.ai/dharma/Manhattan5x3_GA/runs/17d2zzh6</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_082114-17d2zzh6\logs</code>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-bc7ec63dac21> in <module>
#      39         "config_file":config_file,
#      40         "collision_penalty": collision_penalty[run],
# ---> 41         "waiting_time_weight": waiting_time_weight[run],
#      42         "emissions_weight": emissions_weight[run],
#      43         "architecture": "Genetic Algorithm",
#
# IndexError: list index out of range

# %%
GA.visualize_SUMO(GA_pop.best_individual)
